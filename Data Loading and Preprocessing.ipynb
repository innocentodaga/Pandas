# %%
import pandas as pd

# %%
data_csv = pd.read_csv("Sales_January_2019.csv")

# %%
data_csv
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
# using the header 
data_csv.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   141234                      iPhone                1        700
# 1   141235    Lightning Charging Cable                1      14.95
# 2   141236            Wired Headphones                2      11.99
# 3   141237            27in FHD Monitor                1     149.99
# 4   141238            Wired Headphones                1      11.99
# 5   141239      AAA Batteries (4-pack)                1       2.99
# 6   141240      27in 4K Gaming Monitor                1     389.99
# 7   141241        USB-C Charging Cable                1      11.95
# 8   141242  Bose SoundSport Headphones                1      99.99
# 9   141243    Apple Airpods Headphones                1        150
#
#        Order Date                         Purchase Address
# 0  01/22/19 21:25          944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15         185 Maple St, Portland, OR 97035
# ...

# %%
# bottom rows
data_csv.tail(9)
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 9714   150493    Lightning Charging Cable                1      14.95
# 9715   150494      AAA Batteries (4-pack)                1       2.99
# 9716   150495  Bose SoundSport Headphones                1      99.99
# 9717   150496  Bose SoundSport Headphones                1      99.99
# 9718   150497                20in Monitor                1     109.99
# 9719   150498            27in FHD Monitor                1     149.99
# 9720   150499             ThinkPad Laptop                1     999.99
# 9721   150500      AAA Batteries (4-pack)                2       2.99
# 9722   150501                Google Phone                1        600
#
#           Order Date                      Purchase Address
# 9714  01/08/19 15:10    431 Lakeview St, Seattle, WA 98101
# 9715  01/05/19 21:27        435 10th St, Seattle, WA 98101
# 9716  01/15/19 09:33        581 Adams St, Dallas, TX 75001
# ...

# %%
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9723 entries, 0 to 9722
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          9697 non-null   object
#  1   Product           9697 non-null   object
#  2   Quantity Ordered  9697 non-null   object
#  3   Price Each        9697 non-null   object
#  4   Order Date        9697 non-null   object
#  5   Purchase Address  9697 non-null   object
# dtypes: object(6)
# memory usage: 455.9+ KB

# %%
# Checking for null values
data_csv.dropna()
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
# filling the missing values
data_csv.fillna("NULL")
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
# Removing duplicates
data_csv.drop_duplicates()
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
# How to access certain data in the dataframe
data_csv.iloc[10] # used to access specific rows only
# Out:
# Order ID                                            141244
# Product                           Apple Airpods Headphones
# Quantity Ordered                                         1
# Price Each                                             150
# Order Date                                  01/07/19 11:29
# Purchase Address    492 Walnut St, San Francisco, CA 94016
# Name: 10, dtype: object

# %%
# loc() is used to access both rows and colum values

data_csv.loc[5,"Product"]
# Out:
# 'AAA Batteries (4-pack)'

# %%
data = pd.DataFrame({
    "A1": [1, 2, 3],
    "A2": [4, 5, 6],
    "A3": [7, 8, 9]
}, index = ["☓", "Y", "Z"])

# %%
data
# Out:
#    A1  A2  A3
# ☓   1   4   7
# Y   2   5   8
# Z   3   6   9

# %%
data.loc["Z"]
# Out:
# A1    3
# A2    6
# A3    9
# Name: Z, dtype: int64

# %%
data.loc[:, "A1":"A2"]
# Out:
#    A1  A2
# ☓   1   4
# Y   2   5
# Z   3   6
