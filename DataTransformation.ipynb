# %% [markdown]
# ## Data Transformation
#
# * converting data to categorical datatype

# %%
import pandas as pd

df = pd.read_csv("datasets/employees.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# To find the frequency of the data i.e of the column gender
df.Gender.value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
# to find the number of non values
df.Gender.isna().sum()
# Out:
# 145

# %%
# CONVERTING TO CATEGORICAL TYPE
pd.Categorical(df.Gender)
# Out:
# ['Male', 'Male', 'Female', 'Male', 'Male', ..., NaN, 'Male', 'Male', 'Male', 'Male']
# Length: 1000
# Categories (2, object): ['Female', 'Male']

# %%
# Creating a new column
df["Gender2"] = pd.Categorical(df.Gender)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2
# 0              True        Marketing    Male
# 1              True              NaN    Male
# 2             False          Finance  Female
# 3              True          Finance    Male
# 4              True  Client Services    Male

# %%
df.memory_usage()
# Out:
# Index                 132
# First Name           8000
# Gender               8000
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# dtype: int64

# %%
import random
random.choices(["Very Low","Low","Medium","High","Very High"], k = 1000)
# Out:
# ['High',
#  'Medium',
#  'Low',
#  'Very Low',
#  'High',
#  'Very Low',
#  'High',
#  'Very Low',
#  'Medium',
#  'Very Low',
#  'Low',
#  'Low',
#  'Medium',
#  'Low',
#  'Medium',
#  'High',
#  'Low',
#  'Very High',
#  'Medium',
#  'High',
#  'Low',
#  'Low',
#  'Medium',
#  'Very High',
#  'High',
#  'Medium',
#  'Low',
#  'Low',
#  'Very High',
#  'Medium',
#  'Medium',
#  'Very Low',
#  'High',
#  'Very High',
#  'Medium',
#  'Low',
#  'High',
#  'High',
#  'Low',
#  'Medium',
#  'Very High',
#  'Very Low',
#  'Low',
#  'High',
#  'Very Low',
#  'High',
#  'Very Low',
#  'Medium',
#  'Very High',
#  'Medium',
#  'High',
#  'Very Low',
#  'Very High',
#  'Low',
#  'High',
#  'Low',
#  'Low',
#  'High',
#  'Medium',
#  'Very Low',
#  'Very High',
#  'Low',
#  'High',
#  'Very Low',
#  'Very Low',
#  'Very Low',
#  'High',
#  'Medium',
#  'Low',
#  'Medium',
#  'Very High',
#  'Low',
#  'Very Low',
#  'Very High',
#  'Very Low',
#  'High',
#  'Medium',
#  'Very Low',
# ...

# %%
df["Score"] = pd.Series(random.choices(["Very Low","Low","Medium","High","Very High"], k = 1000))

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2      Score
# 0              True        Marketing    Male     Medium
# 1              True              NaN    Male        Low
# 2             False          Finance  Female        Low
# 3              True          Finance    Male  Very High
# 4              True  Client Services    Male   Very Low

# %%
df.dtypes
# Out:
# First Name             object
# Gender                 object
# Start Date             object
# Last Login Time        object
# Salary                  int64
# Bonus %               float64
# Senior Management      object
# Team                   object
# Gender2              category
# Score                  object
# dtype: object

# %%
pd.Categorical(df.Score)
# Out:
# ['Medium', 'Low', 'Low', 'Very High', 'Very Low', ..., 'High', 'Very High', 'Medium', 'Very Low', 'Very High']
# Length: 1000
# Categories (5, object): ['High', 'Low', 'Medium', 'Very High', 'Very Low']

# %%
# Chaging the lexical order of the categorical data
pd.Categorical(df.Score, categories=['High', 'Low', 'Medium', 'Very High', 'Very Low'], ordered=True)
# Out:
# ['Medium', 'Low', 'Low', 'Very High', 'Very Low', ..., 'High', 'Very High', 'Medium', 'Very Low', 'Very High']
# Length: 1000
# Categories (5, object): ['High' < 'Low' < 'Medium' < 'Very High' < 'Very Low']

# %%
# adding the above to the dataframe
df["Score2"] = pd.Categorical(df.Score, categories=['High', 'Low', 'Medium', 'Very High', 'Very Low'], ordered=True)

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team Gender2      Score     Score2
# 0                True             Marketing    Male     Medium     Medium
# ...

# %%
# to find the  number of people whose score2 > medium of the score2 columns
sum(df.Score2 > 'Medium')
# Out:
# 409

# %%
# Finding max and min of the salary
df.Salary.min()
# Out:
# 35013

# %%
df.Salary.max()
# Out:
# 149908

# %%
pd.cut(df.Salary, bins = [35000, 50000,75000,100000,125000, 150000], labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High'])
# Out:
# 0         Medium
# 1            Low
# 2      Very High
# 3      Very High
# 4           High
#          ...
# 995    Very High
# 996     Very Low
# 997       Medium
# 998          Low
# 999    Very High
# Name: Salary, Length: 1000, dtype: category
# Categories (5, object): ['Very Low' < 'Low' < 'Medium' < 'High' < 'Very High']

# %%
# creating a category column for the above 
df["Salary_Cat"] = pd.cut(df.Salary, bins = [35000, 50000,75000,100000,125000, 150000], labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2      Score     Score2 Salary_Cat
# 0              True        Marketing    Male     Medium     Medium     Medium
# 1              True              NaN    Male        Low        Low        Low
# 2             False          Finance  Female        Low        Low  Very High
# 3              True          Finance    Male  Very High  Very High  Very High
# 4              True  Client Services    Male   Very Low   Very Low       High
